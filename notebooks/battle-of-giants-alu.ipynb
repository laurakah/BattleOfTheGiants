# %% [markdown]
# # Import Libraries

# %%
import pandas as pd, numpy as np
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import plotly_express as px

sns.set_style("whitegrid") # set some seaborn styles
sns.set_style("ticks")

pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 300)
pd.set_option("display.max_colwidth", 500)

# %% [markdown]
# # Import Data

# %%
df_raw = pd.read_csv("../data_raw/multiple_choice_responses_2019.csv", low_memory=False)

# %% [markdown]
# # 1. Review / cleaning

# %%
df_raw["Q3"].value_counts()
# Out:
# India                                                   4786
# United States of America                                3085
# Other                                                   1054
# Brazil                                                   728
# Japan                                                    673
# Russia                                                   626
# China                                                    574
# Germany                                                  531
# United Kingdom of Great Britain and Northern Ireland     482
# Canada                                                   450
# Spain                                                    399
# Nigeria                                                  395
# France                                                   387
# Taiwan                                                   301
# Turkey                                                   288
# Italy                                                    271
# Australia                                                269
# Poland                                                   212
# Pakistan                                                 210
# Mexico                                                   195
# Ukraine                                                  191
# South Korea                                              182
# Colombia                                                 168
# Indonesia                                                167
# Netherlands                                              161
# Singapore                                                156
# Bangladesh                                               136
# Viet Nam                                                 128
# Morocco                                                  123
# Argentina                                                123
# Egypt                                                    122
# South Africa                                             120
# Kenya                                                    114
# Portugal                                                 114
# Greece                                                   108
# Israel                                                   104
# Switzerland                                               97
# Iran, Islamic Republic of...                              96
# Sweden                                                    92
# Chile                                                     91
# Ireland                                                   89
# Malaysia                                                  80
# Peru                                                      74
# Republic of Korea                                         73
# Belgium                                                   70
# Belarus                                                   68
# Tunisia                                                   68
# Thailand                                                  67
# Philippines                                               65
# Hong Kong (S.A.R.)                                        64
# Romania                                                   58
# Czech Republic                                            58
# Algeria                                                   58
# Hungary                                                   56
# Denmark                                                   55
# Austria                                                   53
# New Zealand                                               51
# Norway                                                    51
# Saudi Arabia                                              50
# In which country do you currently reside?                  1
# Name: Q3, dtype: int64

# %%
# get overview, search isnull. 
100 * df_raw.isnull().sum() / len(df_raw)
# Out:
# Time from Start to Finish (seconds)     0.000000
# Q1                                      0.000000
# Q2                                      0.000000
# Q2_OTHER_TEXT                           0.000000
# Q3                                      0.000000
# Q4                                      1.998174
# Q5                                      3.093620
# Q5_OTHER_TEXT                           0.000000
# Q6                                     28.983670
# Q7                                     30.905771
# Q8                                     32.914089
# Q9_Part_1                              69.104372
# Q9_Part_2                              81.909930
# Q9_Part_3                              74.733746
# Q9_Part_4                              83.015519
# Q9_Part_5                              81.204990
# Q9_Part_6                              88.031240
# Q9_Part_7                              97.301958
# Q9_Part_8                              98.732123
# Q9_OTHER_TEXT                           0.000000
# Q10                                    36.616290
# Q11                                    37.868952
# Q12_Part_1                             81.027488
# Q12_Part_2                             90.845928
# Q12_Part_3                             82.655442
# Q12_Part_4                             45.471143
# Q12_Part_5                             80.951415
# Q12_Part_6                             61.765899
# Q12_Part_7                             89.471549
# Q12_Part_8                             49.751496
# Q12_Part_9                             77.315144
# Q12_Part_10                            87.762451
# Q12_Part_11                            97.078811
# Q12_Part_12                            93.990263
# Q12_OTHER_TEXT                          0.000000
# Q13_Part_1                             85.018765
# Q13_Part_2                             55.948879
# Q13_Part_3                             84.019677
# Q13_Part_4                             80.505122
# Q13_Part_5                             96.226798
# Q13_Part_6                             74.033878
# Q13_Part_7                             92.286236
# Q13_Part_8                             75.631403
# Q13_Part_9                             93.488183
# Q13_Part_10                            77.284714
# Q13_Part_11                            92.433310
# Q13_Part_12                            90.501065
# Q13_OTHER_TEXT                          0.000000
# Q14                                    20.422964
# Q14_Part_1_TEXT                         0.000000
# Q14_Part_2_TEXT                         0.000000
# Q14_Part_3_TEXT                         0.000000
# Q14_Part_4_TEXT                         0.000000
# Q14_Part_5_TEXT                         0.000000
# Q14_OTHER_TEXT                          0.000000
# Q15                                    20.742469
# Q16_Part_1                             45.202353
# Q16_Part_2                             77.401359
# Q16_Part_3                             78.572878
# Q16_Part_4                             92.453596
# Q16_Part_5                             91.028502
# Q16_Part_6                             77.000710
# Q16_Part_7                             84.349325
# Q16_Part_8                             90.957501
# Q16_Part_9                             83.355310
# Q16_Part_10                            86.530074
# Q16_Part_11                            98.787910
# Q16_Part_12                            96.490516
# Q16_OTHER_TEXT                          0.000000
# Q17_Part_1                             75.423471
# Q17_Part_2                             76.914494
# Q17_Part_3                             95.658789
# Q17_Part_4                             94.309768
# Q17_Part_5                             99.274774
# Q17_Part_6                             99.482706
# Q17_Part_7                             91.469723
# Q17_Part_8                             96.602089
# Q17_Part_9                             99.609494
# Q17_Part_10                            96.155797
# Q17_Part_11                            73.739730
# Q17_Part_12                            97.662035
# Q17_OTHER_TEXT                          0.000000
# Q18_Part_1                             34.871691
# Q18_Part_2                             76.726849
# Q18_Part_3                             66.867836
# Q18_Part_4                             91.515367
# Q18_Part_5                             88.553606
# Q18_Part_6                             88.497819
# Q18_Part_7                             88.969470
# Q18_Part_8                             98.022112
# Q18_Part_9                             89.664266
# Q18_Part_10                            92.306522
# Q18_Part_11                            99.573993
# Q18_Part_12                            94.172837
# Q18_OTHER_TEXT                          0.000000
# Q19                                    27.081854
# Q19_OTHER_TEXT                          0.000000
# Q20_Part_1                             78.785881
# Q20_Part_2                             46.662948
# Q20_Part_3                             99.147987
# Q20_Part_4                             93.685972
# Q20_Part_5                             94.527843
# Q20_Part_6                             83.679886
# Q20_Part_7                             94.705345
# Q20_Part_8                             64.976164
# Q20_Part_9                             96.728877
# Q20_Part_10                            97.205599
# Q20_Part_11                            93.706258
# Q20_Part_12                            97.636677
# Q20_OTHER_TEXT                          0.000000
# Q21_Part_1                             46.886094
# Q21_Part_2                             66.330257
# Q21_Part_3                             97.479460
# Q21_Part_4                             87.574805
# Q21_Part_5                             99.447206
# Q21_OTHER_TEXT                          0.000000
# Q22                                    27.964297
# Q23                                    28.070798
# Q24_Part_1                             48.148899
# Q24_Part_2                             56.937823
# Q24_Part_3                             71.903844
# Q24_Part_4                             81.103560
# Q24_Part_5                             95.603002
# Q24_Part_6                             83.142307
# Q24_Part_7                             72.355208
# Q24_Part_8                             95.040065
# Q24_Part_9                             82.807587
# Q24_Part_10                            95.395070
# Q24_Part_11                            93.980120
# Q24_Part_12                            97.859824
# Q24_OTHER_TEXT                          0.000000
# Q25_Part_1                             90.866214
# Q25_Part_2                             92.362309
# Q25_Part_3                             83.766102
# Q25_Part_4                             97.712750
# Q25_Part_5                             90.977787
# Q25_Part_6                             94.020692
# Q25_Part_7                             60.325591
# Q25_Part_8                             98.833553
# Q25_OTHER_TEXT                          0.000000
# Q26_Part_1                             88.802110
# Q26_Part_2                             89.542550
# Q26_Part_3                             90.501065
# Q26_Part_4                             83.832032
# Q26_Part_5                             94.512628
# Q26_Part_6                             93.893904
# Q26_Part_7                             99.736282
# Q26_OTHER_TEXT                          0.000000
# Q27_Part_1                             89.268689
# Q27_Part_2                             93.057105
# Q27_Part_3                             97.144741
# Q27_Part_4                             94.766203
# Q27_Part_5                             94.786490
# Q27_Part_6                             99.746425
# Q27_OTHER_TEXT                          0.000000
# Q28_Part_1                             52.373466
# Q28_Part_2                             70.468607
# Q28_Part_3                             70.803327
# Q28_Part_4                             77.051425
# Q28_Part_5                             78.476519
# Q28_Part_6                             82.690942
# Q28_Part_7                             94.218481
# Q28_Part_8                             89.010042
# Q28_Part_9                             95.379856
# Q28_Part_10                            95.182067
# Q28_Part_11                            91.271934
# Q28_Part_12                            98.260473
# Q28_OTHER_TEXT                          0.000000
# Q29_Part_1                             89.172330
# Q29_Part_2                             86.007709
# Q29_Part_3                             93.117963
# Q29_Part_4                             98.103256
# Q29_Part_5                             99.437063
# Q29_Part_6                             99.411705
# Q29_Part_7                             99.173344
# Q29_Part_8                             99.538493
# Q29_Part_9                             99.127701
# Q29_Part_10                            99.599351
# Q29_Part_11                            88.690537
# Q29_Part_12                            99.132772
# Q29_OTHER_TEXT                          0.000000
# Q30_Part_1                             90.815499
# Q30_Part_2                             94.223552
# Q30_Part_3                             95.552287
# Q30_Part_4                             95.745005
# Q30_Part_5                             96.967238
# Q30_Part_6                             96.434730
# Q30_Part_7                             98.417689
# Q30_Part_8                             97.327315
# Q30_Part_9                             98.554620
# Q30_Part_10                            97.991683
# Q30_Part_11                            83.994320
# Q30_Part_12                            98.782838
# Q30_OTHER_TEXT                          0.000000
# Q31_Part_1                             95.136424
# Q31_Part_2                             97.144741
# Q31_Part_3                             96.931737
# Q31_Part_4                             97.819251
# Q31_Part_5                             98.361903
# Q31_Part_6                             97.834466
# Q31_Part_7                             97.332387
# Q31_Part_8                             98.123542
# Q31_Part_9                             98.569835
# Q31_Part_10                            97.976468
# Q31_Part_11                            79.034385
# Q31_Part_12                            98.645907
# Q31_OTHER_TEXT                          0.000000
# Q32_Part_1                             97.712750
# Q32_Part_2                             97.875038
# Q32_Part_3                             97.048382
# Q32_Part_4                             97.023025
# Q32_Part_5                             98.108327
# Q32_Part_6                             97.773608
# Q32_Part_7                             97.966325
# Q32_Part_8                             98.650979
# Q32_Part_9                             98.397403
# Q32_Part_10                            97.109240
# Q32_Part_11                            78.121513
# Q32_Part_12                            98.853839
# Q32_OTHER_TEXT                          0.000000
# Q33_Part_1                             97.469317
# Q33_Part_2                             98.590121
# Q33_Part_3                             99.026270
# Q33_Part_4                             99.127701
# Q33_Part_5                             99.102343
# Q33_Part_6                             97.636677
# Q33_Part_7                             96.160868
# Q33_Part_8                             98.579978
# Q33_Part_9                             99.852926
# Q33_Part_10                            99.320418
# Q33_Part_11                            73.749873
# Q33_Part_12                            99.325489
# Q33_OTHER_TEXT                          0.000000
# Q34_Part_1                             84.161680
# Q34_Part_2                             89.040471
# Q34_Part_3                             92.250735
# Q34_Part_4                             90.602495
# Q34_Part_5                             93.949691
# Q34_Part_6                             97.220813
# Q34_Part_7                             97.012882
# Q34_Part_8                             97.890253
# Q34_Part_9                             97.565676
# Q34_Part_10                            97.327315
# Q34_Part_11                            93.680901
# Q34_Part_12                            98.539406
# Q34_OTHER_TEXT                          0.000000
# dtype: float64

# %% [markdown]
# As most cols are dummy vars we dont drop cols with hight perc isnull

# %%
df = df_raw.copy()

# %%
# extract question
questions = df.iloc[0,:]

# %%
# drop questions
df = df.drop(df.index[0])

# %%
# check and drop duplicates
df = df.drop_duplicates()

# %%
# drop columns
## possible to drop later: Q16, Q17, Q20, Q30, Q31, Q32

drop_all = ["Q26", "Time from Start to Finish", "Q11", "Q19"]
#df[df.columns.drop(list(df.filter(regex="Q26", "OTHER", "Time from Start to Finish (seconds)", "Q11", "Q19")))]

for col in drop_all:
    df = df.loc[:,~df.columns.str.contains(col)]

# %%
# rename cols
rename = {"Q1" : "age",
          "Q2" : "gender",
          "Q3" : "country",
          "Q4" : "degree",
          "Q5" : "position",
          "Q6" : "company_size",
          }
df = df.rename(columns=rename)

# %%
df
# Out:
#          age  gender    country               degree           position  \
# 1      22-24    Male     France      Master’s degree  Software Engineer
# 2      40-44    Male      India  Professional degree  Software Engineer
# 3      55-59  Female    Germany  Professional degree                NaN
# 4      40-44    Male  Australia      Master’s degree              Other
# 5      22-24    Male      India    Bachelor’s degree              Other
# ...      ...     ...        ...                  ...                ...
# 19712  18-21    Male      India      Master’s degree            Student
# 19714  18-21    Male      India    Bachelor’s degree              Other
# 19715  35-39    Male      India      Master’s degree            Student
# 19716  25-29    Male      India      Master’s degree       Statistician
# 19717  50-54    Male     France    Bachelor’s degree  Software Engineer
#
#                company_size     Q7  \
# 1      1000-9,999 employees      0
# 2        > 10,000 employees    20+
# 3                       NaN    NaN
# 4        > 10,000 employees    20+
# 5            0-49 employees      0
# ...                     ...    ...
# 19712                   NaN    NaN
# 19714     250-999 employees    3-4
# 19715                   NaN    NaN
# 19716      50-249 employees  15-19
# 19717    > 10,000 employees    20+
#
#                                                                                             Q8  \
# 1                                                                                I do not know
# 2       We have well established ML methods (i.e., models in production for more than 2 years)
# 3                                                                                          NaN
# 4                                                                                I do not know
# 5                                                                No (we do not use ML methods)
# ...                                                                                        ...
# 19712                                                                                      NaN
# 19714                                                                            I do not know
# 19715                                                                                      NaN
# 19716  We recently started using ML methods (i.e., models in production for less than 2 years)
# 19717   We have well established ML methods (i.e., models in production for more than 2 years)
#
#                                                                     Q9_Part_1  \
# 1                                                                         NaN
# 2      Analyze and understand data to influence product or business decisions
# 3                                                                         NaN
# 4                                                                         NaN
# 5                                                                         NaN
# ...                                                                       ...
# 19712                                                                     NaN
# 19714                                                                     NaN
# 19715                                                                     NaN
# 19716                                                                     NaN
# 19717                                                                     NaN
#
#                                                                                                               Q9_Part_2  \
# 1                                                                                                                   NaN
# 2      Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data
# 3                                                                                                                   NaN
# 4                                                                                                                   NaN
# 5                                                                                                                   NaN
# ...                                                                                                                 ...
# 19712                                                                                                               NaN
# 19714                                                                                                               NaN
# 19715                                                                                                               NaN
# 19716                                                                                                               NaN
# 19717  Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data
#
#                                                                 Q9_Part_3  \
# 1                                                                     NaN
# 2      Build prototypes to explore applying machine learning to new areas
# 3                                                                     NaN
# 4                                                                     NaN
# 5                                                                     NaN
# ...                                                                   ...
# 19712                                                                 NaN
# 19714                                                                 NaN
# 19715                                                                 NaN
# 19716                                                                 NaN
# 19717  Build prototypes to explore applying machine learning to new areas
#
#                                                                                              Q9_Part_4  \
# 1                                                                                                  NaN
# 2      Build and/or run a machine learning service that operationally improves my product or workflows
# 3                                                                                                  NaN
# 4                                                                                                  NaN
# 5                                                                                                  NaN
# ...                                                                                                ...
# 19712                                                                                              NaN
# 19714                                                                                              NaN
# 19715                                                                                              NaN
# 19716                                                                                              NaN
# 19717                                                                                              NaN
#
#       Q9_Part_5 Q9_Part_6 Q9_Part_7 Q9_Part_8              Q10  \
# 1           NaN       NaN       NaN       NaN    30,000-39,999
# 2           NaN       NaN       NaN       NaN      5,000-7,499
# 3           NaN       NaN       NaN       NaN              NaN
# 4           NaN       NaN       NaN       NaN  250,000-299,999
# 5           NaN       NaN       NaN       NaN      4,000-4,999
# ...         ...       ...       ...       ...              ...
# 19712       NaN       NaN       NaN       NaN              NaN
# 19714       NaN       NaN       NaN       NaN           $0-999
# 19715       NaN       NaN       NaN       NaN              NaN
# 19716       NaN       NaN       NaN     Other      1,000-1,999
# 19717       NaN       NaN       NaN       NaN    60,000-69,999
#
#                                Q12_Part_1 Q12_Part_2  \
# 1      Twitter (data science influencers)        NaN
# 2                                     NaN        NaN
# 3                                     NaN        NaN
# 4                                     NaN        NaN
# 5                                     NaN        NaN
# ...                                   ...        ...
# 19712                                 NaN        NaN
# 19714                                 NaN        NaN
# 19715                                 NaN        NaN
# 19716                                 NaN        NaN
# 19717                                 NaN        NaN
#
#                                            Q12_Part_3  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# ...                                               ...
# 19712                                             NaN
# 19714  Reddit (r/machinelearning, r/datascience, etc)
# 19715                                             NaN
# 19716                                             NaN
# 19717                                             NaN
#
#                                      Q12_Part_4  \
# 1      Kaggle (forums, blog, social media, etc)
# 2      Kaggle (forums, blog, social media, etc)
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# ...                                         ...
# 19712  Kaggle (forums, blog, social media, etc)
# 19714                                       NaN
# 19715  Kaggle (forums, blog, social media, etc)
# 19716                                       NaN
# 19717                                       NaN
#
#                                 Q12_Part_5  \
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# ...                                    ...
# 19712                                  NaN
# 19714                                  NaN
# 19715  Course Forums (forums.fast.ai, etc)
# 19716                                  NaN
# 19717                                  NaN
#
#                                             Q12_Part_6  \
# 1                                                  NaN
# 2      YouTube (Cloud AI Adventures, Siraj Raval, etc)
# 3                                                  NaN
# 4                                                  NaN
# 5      YouTube (Cloud AI Adventures, Siraj Raval, etc)
# ...                                                ...
# 19712                                              NaN
# 19714                                              NaN
# 19715  YouTube (Cloud AI Adventures, Siraj Raval, etc)
# 19716                                              NaN
# 19717                                              NaN
#
#                                                        Q12_Part_7  \
# 1                                                             NaN
# 2      Podcasts (Chai Time Data Science, Linear Digressions, etc)
# 3                                                             NaN
# 4      Podcasts (Chai Time Data Science, Linear Digressions, etc)
# 5                                                             NaN
# ...                                                           ...
# 19712                                                         NaN
# 19714                                                         NaN
# 19715                                                         NaN
# 19716                                                         NaN
# 19717                                                         NaN
#
#                                                                   Q12_Part_8  \
# 1      Blogs (Towards Data Science, Medium, Analytics Vidhya, KDnuggets etc)
# 2      Blogs (Towards Data Science, Medium, Analytics Vidhya, KDnuggets etc)
# 3                                                                        NaN
# 4      Blogs (Towards Data Science, Medium, Analytics Vidhya, KDnuggets etc)
# 5      Blogs (Towards Data Science, Medium, Analytics Vidhya, KDnuggets etc)
# ...                                                                      ...
# 19712  Blogs (Towards Data Science, Medium, Analytics Vidhya, KDnuggets etc)
# 19714                                                                    NaN
# 19715  Blogs (Towards Data Science, Medium, Analytics Vidhya, KDnuggets etc)
# 19716                                                                    NaN
# 19717  Blogs (Towards Data Science, Medium, Analytics Vidhya, KDnuggets etc)
#
#                                                                     Q12_Part_9  \
# 1      Journal Publications (traditional publications, preprint journals, etc)
# 2                                                                          NaN
# 3                                                                          NaN
# 4      Journal Publications (traditional publications, preprint journals, etc)
# 5                                                                          NaN
# ...                                                                        ...
# 19712  Journal Publications (traditional publications, preprint journals, etc)
# 19714                                                                      NaN
# 19715  Journal Publications (traditional publications, preprint journals, etc)
# 19716                                                                      NaN
# 19717                                                                      NaN
#
#                                         Q12_Part_10 Q12_Part_11 Q12_Part_12  \
# 1                                               NaN         NaN         NaN
# 2                                               NaN         NaN         NaN
# 3                                               NaN         NaN         NaN
# 4      Slack Communities (ods.ai, kagglenoobs, etc)         NaN         NaN
# 5                                               NaN         NaN       Other
# ...                                             ...         ...         ...
# 19712                                           NaN         NaN         NaN
# 19714                                           NaN         NaN         NaN
# 19715                                           NaN         NaN         NaN
# 19716                                           NaN         NaN         NaN
# 19717                                           NaN         NaN         NaN
#
#       Q13_Part_1 Q13_Part_2 Q13_Part_3 Q13_Part_4 Q13_Part_5  \
# 1            NaN   Coursera        NaN   DataCamp        NaN
# 2            NaN   Coursera        NaN   DataCamp        NaN
# 3            NaN        NaN        NaN        NaN        NaN
# 4            NaN   Coursera        edX   DataCamp        NaN
# 5            NaN        NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...        ...
# 19712        NaN   Coursera        NaN        NaN        NaN
# 19714        NaN        NaN        NaN   DataCamp        NaN
# 19715        NaN   Coursera        NaN        NaN        NaN
# 19716        NaN        NaN        NaN        NaN        NaN
# 19717        NaN   Coursera        edX        NaN        NaN
#
#                                Q13_Part_6 Q13_Part_7 Q13_Part_8 Q13_Part_9  \
# 1      Kaggle Courses (i.e. Kaggle Learn)        NaN      Udemy        NaN
# 2      Kaggle Courses (i.e. Kaggle Learn)        NaN      Udemy        NaN
# 3                                     NaN        NaN        NaN        NaN
# 4                                     NaN        NaN        NaN        NaN
# 5                                     NaN        NaN        NaN        NaN
# ...                                   ...        ...        ...        ...
# 19712                                 NaN        NaN        NaN        NaN
# 19714                                 NaN        NaN      Udemy        NaN
# 19715  Kaggle Courses (i.e. Kaggle Learn)        NaN        NaN        NaN
# 19716                                 NaN        NaN        NaN        NaN
# 19717                                 NaN        NaN      Udemy        NaN
#
#                                                  Q13_Part_10 Q13_Part_11  \
# 1                                                        NaN         NaN
# 2                                                        NaN         NaN
# 3                                                        NaN         NaN
# 4      University Courses (resulting in a university degree)         NaN
# 5                                                        NaN         NaN
# ...                                                      ...         ...
# 19712                                                    NaN         NaN
# 19714                                                    NaN         NaN
# 19715                                                    NaN         NaN
# 19716                                                    NaN         NaN
# 19717                                                    NaN         NaN
#
#       Q13_Part_12  \
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5           Other
# ...           ...
# 19712         NaN
# 19714         NaN
# 19715         NaN
# 19716         NaN
# 19717         NaN
#
#                                                                      Q14  \
# 1      Basic statistical software (Microsoft Excel, Google Sheets, etc.)
# 2               Cloud-based data software & APIs (AWS, GCP, Azure, etc.)
# 3                                                                    NaN
# 4             Local development environments (RStudio, JupyterLab, etc.)
# 5             Local development environments (RStudio, JupyterLab, etc.)
# ...                                                                  ...
# 19712                                                                NaN
# 19714         Local development environments (RStudio, JupyterLab, etc.)
# 19715                                                                NaN
# 19716                                                                NaN
# 19717         Local development environments (RStudio, JupyterLab, etc.)
#
#       Q14_Part_1_TEXT Q14_Part_2_TEXT Q14_Part_3_TEXT Q14_Part_4_TEXT  \
# 1                   0              -1              -1              -1
# 2                  -1              -1              -1              -1
# 3                  -1              -1              -1              -1
# 4                  -1              -1              -1               0
# 5                  -1              -1              -1               1
# ...               ...             ...             ...             ...
# 19712              -1              -1              -1              -1
# 19714              -1              -1              -1              28
# 19715              -1              -1              -1              -1
# 19716              -1              -1              -1              -1
# 19717              -1              -1              -1              25
#
#       Q14_Part_5_TEXT                        Q15  \
# 1                  -1                  1-2 years
# 2                   0  I have never written code
# 3                  -1                        NaN
# 4                  -1                  1-2 years
# 5                  -1                  < 1 years
# ...               ...                        ...
# 19712              -1                        NaN
# 19714              -1                  1-2 years
# 19715              -1                        NaN
# 19716              -1                        NaN
# 19717              -1                  3-5 years
#
#                                           Q16_Part_1 Q16_Part_2 Q16_Part_3  \
# 1      Jupyter (JupyterLab, Jupyter Notebooks, etc)    RStudio    PyCharm
# 2                                                NaN        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4      Jupyter (JupyterLab, Jupyter Notebooks, etc)         NaN        NaN
# 5      Jupyter (JupyterLab, Jupyter Notebooks, etc)         NaN        NaN
# ...                                              ...        ...        ...
# 19712                                            NaN        NaN        NaN
# 19714  Jupyter (JupyterLab, Jupyter Notebooks, etc)    RStudio    PyCharm
# 19715                                            NaN        NaN        NaN
# 19716                                            NaN        NaN        NaN
# 19717  Jupyter (JupyterLab, Jupyter Notebooks, etc)         NaN        NaN
#
#       Q16_Part_4 Q16_Part_5                            Q16_Part_6  Q16_Part_7  \
# 1            NaN    MATLAB                                    NaN    Spyder
# 2            NaN        NaN                                   NaN         NaN
# 3            NaN        NaN                                   NaN         NaN
# 4            NaN        NaN   Visual Studio / Visual Studio Code          NaN
# 5            NaN        NaN                                   NaN         NaN
# ...          ...        ...                                   ...         ...
# 19712        NaN        NaN                                   NaN         NaN
# 19714        NaN        NaN   Visual Studio / Visual Studio Code     Spyder
# 19715        NaN        NaN                                   NaN         NaN
# 19716        NaN        NaN                                   NaN         NaN
# 19717        NaN        NaN   Visual Studio / Visual Studio Code          NaN
#
#       Q16_Part_8     Q16_Part_9       Q16_Part_10 Q16_Part_11 Q16_Part_12  \
# 1            NaN            NaN               NaN         NaN         NaN
# 2            NaN            NaN               NaN         NaN         NaN
# 3            NaN            NaN               NaN         NaN         NaN
# 4            NaN            NaN               NaN         NaN         NaN
# 5            NaN            NaN               NaN         NaN         NaN
# ...          ...            ...               ...         ...         ...
# 19712        NaN            NaN               NaN         NaN         NaN
# 19714        NaN    Notepad++      Sublime Text           NaN         NaN
# 19715        NaN            NaN               NaN         NaN         NaN
# 19716        NaN            NaN               NaN         NaN         NaN
# 19717        NaN            NaN               NaN         NaN         NaN
#
#       Q17_Part_1      Q17_Part_2                   Q17_Part_3  \
# 1            NaN             NaN                          NaN
# 2            NaN             NaN                          NaN
# 3            NaN             NaN                          NaN
# 4            NaN             NaN   Microsoft Azure Notebooks
# 5            NaN   Google Colab                           NaN
# ...          ...             ...                          ...
# 19712        NaN             NaN                          NaN
# 19714        NaN             NaN                          NaN
# 19715        NaN             NaN                          NaN
# 19716        NaN             NaN                          NaN
# 19717        NaN             NaN                          NaN
#
#                                                          Q17_Part_4  \
# 1                                                               NaN
# 2                                                               NaN
# 3                                                               NaN
# 4                                                               NaN
# 5       Google Cloud Notebook Products (AI Platform, Datalab, etc)
# ...                                                             ...
# 19712                                                           NaN
# 19714                                                           NaN
# 19715                                                           NaN
# 19716                                                           NaN
# 19717                                                           NaN
#
#       Q17_Part_5 Q17_Part_6 Q17_Part_7           Q17_Part_8 Q17_Part_9  \
# 1            NaN        NaN        NaN                  NaN        NaN
# 2            NaN        NaN        NaN                  NaN        NaN
# 3            NaN        NaN        NaN                  NaN        NaN
# 4            NaN        NaN        NaN                  NaN        NaN
# 5            NaN        NaN        NaN                  NaN        NaN
# ...          ...        ...        ...                  ...        ...
# 19712        NaN        NaN        NaN                  NaN        NaN
# 19714        NaN        NaN        NaN                  NaN        NaN
# 19715        NaN        NaN        NaN                  NaN        NaN
# 19716        NaN        NaN        NaN                  NaN        NaN
# 19717        NaN        NaN        NaN   IBM Watson Studio         NaN
#
#       Q17_Part_10 Q17_Part_11 Q17_Part_12 Q18_Part_1 Q18_Part_2 Q18_Part_3  \
# 1             NaN        None         NaN     Python          R        SQL
# 2             NaN         NaN         NaN        NaN        NaN        NaN
# 3             NaN         NaN         NaN        NaN        NaN        NaN
# 4             NaN         NaN         NaN     Python          R        SQL
# 5             NaN         NaN         NaN     Python        NaN        SQL
# ...           ...         ...         ...        ...        ...        ...
# 19712         NaN         NaN         NaN        NaN        NaN        NaN
# 19714         NaN         NaN         NaN        NaN        NaN        NaN
# 19715         NaN         NaN         NaN        NaN        NaN        NaN
# 19716         NaN         NaN         NaN        NaN        NaN        NaN
# 19717         NaN         NaN         NaN     Python        NaN        SQL
#
#       Q18_Part_4 Q18_Part_5 Q18_Part_6  Q18_Part_7 Q18_Part_8 Q18_Part_9  \
# 1            NaN        NaN       Java  Javascript        NaN        NaN
# 2            NaN        NaN        NaN         NaN        NaN        NaN
# 3            NaN        NaN        NaN         NaN        NaN        NaN
# 4            NaN        NaN        NaN         NaN        NaN       Bash
# 5            NaN        NaN        NaN         NaN        NaN        NaN
# ...          ...        ...        ...         ...        ...        ...
# 19712        NaN        NaN        NaN         NaN        NaN        NaN
# 19714        NaN        NaN        NaN         NaN        NaN        NaN
# 19715        NaN        NaN        NaN         NaN        NaN        NaN
# 19716        NaN        NaN        NaN         NaN        NaN        NaN
# 19717        NaN        NaN       Java         NaN        NaN       Bash
#
#       Q18_Part_10 Q18_Part_11 Q18_Part_12          Q20_Part_1    Q20_Part_2  \
# 1          MATLAB         NaN         NaN                 NaN   Matplotlib
# 2             NaN         NaN         NaN                 NaN           NaN
# 3             NaN         NaN         NaN                 NaN           NaN
# 4             NaN         NaN         NaN   Ggplot / ggplot2    Matplotlib
# 5             NaN         NaN         NaN                 NaN   Matplotlib
# ...           ...         ...         ...                 ...           ...
# 19712         NaN         NaN         NaN                 NaN           NaN
# 19714         NaN         NaN         NaN                 NaN           NaN
# 19715         NaN         NaN         NaN                 NaN           NaN
# 19716         NaN         NaN         NaN                 NaN           NaN
# 19717         NaN         NaN         NaN                 NaN   Matplotlib
#
#       Q20_Part_3 Q20_Part_4 Q20_Part_5                 Q20_Part_6 Q20_Part_7  \
# 1            NaN        NaN        NaN                        NaN        NaN
# 2            NaN        NaN        NaN                        NaN        NaN
# 3            NaN        NaN        NaN                        NaN        NaN
# 4            NaN        NaN        NaN                        NaN        NaN
# 5            NaN        NaN        NaN   Plotly / Plotly Express         NaN
# ...          ...        ...        ...                        ...        ...
# 19712        NaN        NaN        NaN                        NaN        NaN
# 19714        NaN        NaN        NaN                        NaN        NaN
# 19715        NaN        NaN        NaN                        NaN        NaN
# 19716        NaN        NaN        NaN                        NaN        NaN
# 19717        NaN        NaN        NaN                        NaN        NaN
#
#       Q20_Part_8 Q20_Part_9 Q20_Part_10 Q20_Part_11 Q20_Part_12 Q21_Part_1  \
# 1            NaN        NaN         NaN         NaN         NaN       CPUs
# 2            NaN        NaN         NaN         NaN         NaN        NaN
# 3            NaN        NaN         NaN         NaN         NaN        NaN
# 4       Seaborn         NaN         NaN         NaN         NaN       CPUs
# 5       Seaborn         NaN         NaN         NaN         NaN       CPUs
# ...          ...        ...         ...         ...         ...        ...
# 19712        NaN        NaN         NaN         NaN         NaN        NaN
# 19714        NaN        NaN         NaN         NaN         NaN        NaN
# 19715        NaN        NaN         NaN         NaN         NaN        NaN
# 19716        NaN        NaN         NaN         NaN         NaN        NaN
# 19717        NaN        NaN         NaN         NaN         NaN       CPUs
#
#       Q21_Part_2 Q21_Part_3 Q21_Part_4 Q21_Part_5    Q22        Q23  \
# 1           GPUs        NaN        NaN        NaN  Never  1-2 years
# 2            NaN        NaN        NaN        NaN    NaN        NaN
# 3            NaN        NaN        NaN        NaN    NaN        NaN
# 4           GPUs        NaN        NaN        NaN   Once  2-3 years
# 5           GPUs        NaN        NaN        NaN  Never  < 1 years
# ...          ...        ...        ...        ...    ...        ...
# 19712        NaN        NaN        NaN        NaN    NaN        NaN
# 19714        NaN        NaN        NaN        NaN    NaN        NaN
# 19715        NaN        NaN        NaN        NaN    NaN        NaN
# 19716        NaN        NaN        NaN        NaN    NaN        NaN
# 19717        NaN        NaN        NaN        NaN  Never  4-5 years
#
#                           Q24_Part_1                        Q24_Part_2  \
# 1      Linear or Logistic Regression                               NaN
# 2                                NaN                               NaN
# 3                                NaN                               NaN
# 4      Linear or Logistic Regression                               NaN
# 5      Linear or Logistic Regression  Decision Trees or Random Forests
# ...                              ...                               ...
# 19712                            NaN                               NaN
# 19714                            NaN                               NaN
# 19715                            NaN                               NaN
# 19716                            NaN                               NaN
# 19717  Linear or Logistic Regression  Decision Trees or Random Forests
#
#                                                 Q24_Part_3 Q24_Part_4  \
# 1                                                      NaN        NaN
# 2                                                      NaN        NaN
# 3                                                      NaN        NaN
# 4                                                      NaN        NaN
# 5      Gradient Boosting Machines (xgboost, lightgbm, etc)        NaN
# ...                                                    ...        ...
# 19712                                                  NaN        NaN
# 19714                                                  NaN        NaN
# 19715                                                  NaN        NaN
# 19716                                                  NaN        NaN
# 19717                                                  NaN        NaN
#
#       Q24_Part_5 Q24_Part_6                     Q24_Part_7 Q24_Part_8  \
# 1            NaN        NaN                            NaN        NaN
# 2            NaN        NaN                            NaN        NaN
# 3            NaN        NaN                            NaN        NaN
# 4            NaN        NaN  Convolutional Neural Networks        NaN
# 5            NaN        NaN                            NaN        NaN
# ...          ...        ...                            ...        ...
# 19712        NaN        NaN                            NaN        NaN
# 19714        NaN        NaN                            NaN        NaN
# 19715        NaN        NaN                            NaN        NaN
# 19716        NaN        NaN                            NaN        NaN
# 19717        NaN        NaN                            NaN        NaN
#
#       Q24_Part_9 Q24_Part_10 Q24_Part_11 Q24_Part_12 Q25_Part_1 Q25_Part_2  \
# 1            NaN         NaN         NaN         NaN        NaN        NaN
# 2            NaN         NaN         NaN         NaN        NaN        NaN
# 3            NaN         NaN         NaN         NaN        NaN        NaN
# 4            NaN         NaN         NaN         NaN        NaN        NaN
# 5            NaN         NaN         NaN         NaN        NaN        NaN
# ...          ...         ...         ...         ...        ...        ...
# 19712        NaN         NaN         NaN         NaN        NaN        NaN
# 19714        NaN         NaN         NaN         NaN        NaN        NaN
# 19715        NaN         NaN         NaN         NaN        NaN        NaN
# 19716        NaN         NaN         NaN         NaN        NaN        NaN
# 19717        NaN         NaN         NaN         NaN        NaN        NaN
#
#                                                    Q25_Part_3 Q25_Part_4  \
# 1                                                         NaN        NaN
# 2                                                         NaN        NaN
# 3                                                         NaN        NaN
# 4                                                         NaN        NaN
# 5                                                         NaN        NaN
# ...                                                       ...        ...
# 19712                                                     NaN        NaN
# 19714                                                     NaN        NaN
# 19715                                                     NaN        NaN
# 19716                                                     NaN        NaN
# 19717  Automated model selection (e.g. auto-sklearn, xcessiv)        NaN
#
#                                                       Q25_Part_5  \
# 1                                                            NaN
# 2                                                            NaN
# 3                                                            NaN
# 4                                                            NaN
# 5                                                            NaN
# ...                                                          ...
# 19712                                                        NaN
# 19714                                                        NaN
# 19715                                                        NaN
# 19716                                                        NaN
# 19717  Automated hyperparameter tuning (e.g. hyperopt, ray.tune)
#
#                                                                     Q25_Part_6  \
# 1                                                                          NaN
# 2                                                                          NaN
# 3                                                                          NaN
# 4      Automation of full ML pipelines (e.g. Google AutoML, H20 Driverless AI)
# 5                                                                          NaN
# ...                                                                        ...
# 19712                                                                      NaN
# 19714                                                                      NaN
# 19715                                                                      NaN
# 19716                                                                      NaN
# 19717                                                                      NaN
#
#       Q25_Part_7 Q25_Part_8 Q27_Part_1 Q27_Part_2 Q27_Part_3 Q27_Part_4  \
# 1           None        NaN        NaN        NaN        NaN        NaN
# 2            NaN        NaN        NaN        NaN        NaN        NaN
# 3            NaN        NaN        NaN        NaN        NaN        NaN
# 4            NaN        NaN        NaN        NaN        NaN        NaN
# 5           None        NaN        NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...        ...        ...
# 19712        NaN        NaN        NaN        NaN        NaN        NaN
# 19714        NaN        NaN        NaN        NaN        NaN        NaN
# 19715        NaN        NaN        NaN        NaN        NaN        NaN
# 19716        NaN        NaN        NaN        NaN        NaN        NaN
# 19717        NaN        NaN        NaN        NaN        NaN        NaN
#
#       Q27_Part_5 Q27_Part_6       Q28_Part_1     Q28_Part_2 Q28_Part_3  \
# 1            NaN        NaN              NaN            NaN        NaN
# 2            NaN        NaN              NaN            NaN        NaN
# 3            NaN        NaN              NaN            NaN        NaN
# 4            NaN        NaN    Scikit-learn     TensorFlow      Keras
# 5            NaN        NaN    Scikit-learn             NaN        NaN
# ...          ...        ...              ...            ...        ...
# 19712        NaN        NaN              NaN            NaN        NaN
# 19714        NaN        NaN              NaN            NaN        NaN
# 19715        NaN        NaN              NaN            NaN        NaN
# 19716        NaN        NaN              NaN            NaN        NaN
# 19717        NaN        NaN    Scikit-learn             NaN        NaN
#
#           Q28_Part_4 Q28_Part_5 Q28_Part_6 Q28_Part_7  Q28_Part_8  \
# 1                NaN        NaN        NaN        NaN         NaN
# 2                NaN        NaN        NaN        NaN         NaN
# 3                NaN        NaN        NaN        NaN         NaN
# 4       RandomForest        NaN        NaN        NaN         NaN
# 5       RandomForest   Xgboost         NaN        NaN   LightGBM
# ...              ...        ...        ...        ...         ...
# 19712            NaN        NaN        NaN        NaN         NaN
# 19714            NaN        NaN        NaN        NaN         NaN
# 19715            NaN        NaN        NaN        NaN         NaN
# 19716            NaN        NaN        NaN        NaN         NaN
# 19717            NaN        NaN        NaN        NaN         NaN
#
#          Q28_Part_9 Q28_Part_10 Q28_Part_11 Q28_Part_12 Q29_Part_1 Q29_Part_2  \
# 1               NaN         NaN        None         NaN        NaN        NaN
# 2               NaN         NaN         NaN         NaN        NaN        NaN
# 3               NaN         NaN         NaN         NaN        NaN        NaN
# 4               NaN         NaN         NaN         NaN        NaN        NaN
# 5               NaN         NaN         NaN         NaN        NaN        NaN
# ...             ...         ...         ...         ...        ...        ...
# 19712           NaN         NaN         NaN         NaN        NaN        NaN
# 19714           NaN         NaN         NaN         NaN        NaN        NaN
# 19715           NaN         NaN         NaN         NaN        NaN        NaN
# 19716           NaN         NaN         NaN         NaN        NaN        NaN
# 19717   Spark MLib          NaN         NaN         NaN        NaN        NaN
#
#               Q29_Part_3 Q29_Part_4 Q29_Part_5 Q29_Part_6 Q29_Part_7  \
# 1                    NaN        NaN        NaN        NaN        NaN
# 2                    NaN        NaN        NaN        NaN        NaN
# 3                    NaN        NaN        NaN        NaN        NaN
# 4       Microsoft Azure         NaN        NaN        NaN        NaN
# 5                    NaN        NaN        NaN        NaN        NaN
# ...                  ...        ...        ...        ...        ...
# 19712                NaN        NaN        NaN        NaN        NaN
# 19714                NaN        NaN        NaN        NaN        NaN
# 19715                NaN        NaN        NaN        NaN        NaN
# 19716                NaN        NaN        NaN        NaN        NaN
# 19717                NaN        NaN        NaN        NaN        NaN
#
#       Q29_Part_8 Q29_Part_9 Q29_Part_10 Q29_Part_11 Q29_Part_12 Q30_Part_1  \
# 1            NaN        NaN         NaN         NaN         NaN        NaN
# 2            NaN        NaN         NaN         NaN         NaN        NaN
# 3            NaN        NaN         NaN         NaN         NaN        NaN
# 4            NaN        NaN         NaN         NaN         NaN        NaN
# 5            NaN        NaN         NaN         NaN         NaN        NaN
# ...          ...        ...         ...         ...         ...        ...
# 19712        NaN        NaN         NaN         NaN         NaN        NaN
# 19714        NaN        NaN         NaN         NaN         NaN        NaN
# 19715        NaN        NaN         NaN         NaN         NaN        NaN
# 19716        NaN        NaN         NaN         NaN         NaN        NaN
# 19717        NaN        NaN         NaN         NaN         NaN        NaN
#
#       Q30_Part_2 Q30_Part_3              Q30_Part_4 Q30_Part_5 Q30_Part_6  \
# 1            NaN        NaN                     NaN        NaN        NaN
# 2            NaN        NaN                     NaN        NaN        NaN
# 3            NaN        NaN                     NaN        NaN        NaN
# 4            NaN        NaN  Azure Virtual Machines        NaN        NaN
# 5            NaN        NaN                     NaN        NaN        NaN
# ...          ...        ...                     ...        ...        ...
# 19712        NaN        NaN                     NaN        NaN        NaN
# 19714        NaN        NaN                     NaN        NaN        NaN
# 19715        NaN        NaN                     NaN        NaN        NaN
# 19716        NaN        NaN                     NaN        NaN        NaN
# 19717        NaN        NaN                     NaN        NaN        NaN
#
#       Q30_Part_7 Q30_Part_8 Q30_Part_9              Q30_Part_10 Q30_Part_11  \
# 1            NaN        NaN        NaN                      NaN         NaN
# 2            NaN        NaN        NaN                      NaN         NaN
# 3            NaN        NaN        NaN                      NaN         NaN
# 4            NaN        NaN        NaN  Azure Container Service         NaN
# 5            NaN        NaN        NaN                      NaN         NaN
# ...          ...        ...        ...                      ...         ...
# 19712        NaN        NaN        NaN                      NaN         NaN
# 19714        NaN        NaN        NaN                      NaN         NaN
# 19715        NaN        NaN        NaN                      NaN         NaN
# 19716        NaN        NaN        NaN                      NaN         NaN
# 19717        NaN        NaN        NaN                      NaN         NaN
#
#       Q30_Part_12 Q31_Part_1 Q31_Part_2  Q31_Part_3 Q31_Part_4 Q31_Part_5  \
# 1             NaN        NaN        NaN         NaN        NaN        NaN
# 2             NaN        NaN        NaN         NaN        NaN        NaN
# 3             NaN        NaN        NaN         NaN        NaN        NaN
# 4             NaN        NaN        NaN  Databricks        NaN        NaN
# 5             NaN        NaN        NaN         NaN        NaN        NaN
# ...           ...        ...        ...         ...        ...        ...
# 19712         NaN        NaN        NaN         NaN        NaN        NaN
# 19714         NaN        NaN        NaN         NaN        NaN        NaN
# 19715         NaN        NaN        NaN         NaN        NaN        NaN
# 19716         NaN        NaN        NaN         NaN        NaN        NaN
# 19717         NaN        NaN        NaN         NaN        NaN        NaN
#
#                         Q31_Part_6 Q31_Part_7 Q31_Part_8 Q31_Part_9  \
# 1                              NaN        NaN        NaN        NaN
# 2                              NaN        NaN        NaN        NaN
# 3                              NaN        NaN        NaN        NaN
# 4      Microsoft Analysis Services        NaN        NaN        NaN
# 5                              NaN        NaN        NaN        NaN
# ...                            ...        ...        ...        ...
# 19712                          NaN        NaN        NaN        NaN
# 19714                          NaN        NaN        NaN        NaN
# 19715                          NaN        NaN        NaN        NaN
# 19716                          NaN        NaN        NaN        NaN
# 19717                          NaN        NaN        NaN        NaN
#
#       Q31_Part_10 Q31_Part_11 Q31_Part_12 Q32_Part_1 Q32_Part_2  \
# 1             NaN         NaN         NaN        NaN        NaN
# 2             NaN         NaN         NaN        NaN        NaN
# 3             NaN         NaN         NaN        NaN        NaN
# 4             NaN         NaN         NaN        NaN        NaN
# 5             NaN         NaN         NaN        NaN        NaN
# ...           ...         ...         ...        ...        ...
# 19712         NaN         NaN         NaN        NaN        NaN
# 19714         NaN         NaN         NaN        NaN        NaN
# 19715         NaN         NaN         NaN        NaN        NaN
# 19716         NaN         NaN         NaN        NaN        NaN
# 19717         NaN         NaN         NaN        NaN        NaN
#
#                           Q32_Part_3 Q32_Part_4 Q32_Part_5 Q32_Part_6  \
# 1                                NaN        NaN        NaN        NaN
# 2                                NaN        NaN        NaN        NaN
# 3                                NaN        NaN        NaN        NaN
# 4      Azure Machine Learning Studio        NaN        NaN        NaN
# 5                                NaN        NaN        NaN        NaN
# ...                              ...        ...        ...        ...
# 19712                            NaN        NaN        NaN        NaN
# 19714                            NaN        NaN        NaN        NaN
# 19715                            NaN        NaN        NaN        NaN
# 19716                            NaN        NaN        NaN        NaN
# 19717                            NaN        NaN        NaN        NaN
#
#       Q32_Part_7 Q32_Part_8 Q32_Part_9 Q32_Part_10 Q32_Part_11 Q32_Part_12  \
# 1            NaN        NaN        NaN         NaN         NaN         NaN
# 2            NaN        NaN        NaN         NaN         NaN         NaN
# 3            NaN        NaN        NaN         NaN         NaN         NaN
# 4            NaN        NaN        NaN         NaN         NaN         NaN
# 5            NaN        NaN        NaN         NaN         NaN         NaN
# ...          ...        ...        ...         ...         ...         ...
# 19712        NaN        NaN        NaN         NaN         NaN         NaN
# 19714        NaN        NaN        NaN         NaN         NaN         NaN
# 19715        NaN        NaN        NaN         NaN         NaN         NaN
# 19716        NaN        NaN        NaN         NaN         NaN         NaN
# 19717        NaN        NaN        NaN         NaN         NaN         NaN
#
#       Q33_Part_1 Q33_Part_2 Q33_Part_3 Q33_Part_4 Q33_Part_5 Q33_Part_6  \
# 1            NaN        NaN        NaN        NaN        NaN        NaN
# 2            NaN        NaN        NaN        NaN        NaN        NaN
# 3            NaN        NaN        NaN        NaN        NaN        NaN
# 4            NaN        NaN        NaN        NaN        NaN        NaN
# 5            NaN        NaN        NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...        ...        ...
# 19712        NaN        NaN        NaN        NaN        NaN        NaN
# 19714        NaN        NaN        NaN        NaN        NaN        NaN
# 19715        NaN        NaN        NaN        NaN        NaN        NaN
# 19716        NaN        NaN        NaN        NaN        NaN        NaN
# 19717        NaN        NaN        NaN        NaN        NaN        NaN
#
#       Q33_Part_7 Q33_Part_8 Q33_Part_9 Q33_Part_10 Q33_Part_11 Q33_Part_12  \
# 1            NaN        NaN        NaN         NaN         NaN         NaN
# 2            NaN        NaN        NaN         NaN         NaN         NaN
# 3            NaN        NaN        NaN         NaN         NaN         NaN
# 4            NaN        NaN        NaN         NaN        None         NaN
# 5            NaN        NaN        NaN         NaN         NaN         NaN
# ...          ...        ...        ...         ...         ...         ...
# 19712        NaN        NaN        NaN         NaN         NaN         NaN
# 19714        NaN        NaN        NaN         NaN         NaN         NaN
# 19715        NaN        NaN        NaN         NaN         NaN         NaN
# 19716        NaN        NaN        NaN         NaN         NaN         NaN
# 19717        NaN        NaN        NaN         NaN         NaN         NaN
#
#       Q34_Part_1 Q34_Part_2 Q34_Part_3 Q34_Part_4 Q34_Part_5 Q34_Part_6  \
# 1            NaN        NaN        NaN        NaN        NaN        NaN
# 2            NaN        NaN        NaN        NaN        NaN        NaN
# 3            NaN        NaN        NaN        NaN        NaN        NaN
# 4            NaN        NaN        NaN        NaN        NaN        NaN
# 5            NaN        NaN        NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...        ...        ...
# 19712        NaN        NaN        NaN        NaN        NaN        NaN
# 19714        NaN        NaN        NaN        NaN        NaN        NaN
# 19715        NaN        NaN        NaN        NaN        NaN        NaN
# 19716        NaN        NaN        NaN        NaN        NaN        NaN
# 19717        NaN        NaN        NaN        NaN        NaN        NaN
#
#       Q34_Part_7 Q34_Part_8          Q34_Part_9 Q34_Part_10 Q34_Part_11  \
# 1            NaN        NaN                 NaN         NaN         NaN
# 2            NaN        NaN                 NaN         NaN         NaN
# 3            NaN        NaN                 NaN         NaN         NaN
# 4            NaN        NaN  Azure SQL Database         NaN         NaN
# 5            NaN        NaN                 NaN         NaN         NaN
# ...          ...        ...                 ...         ...         ...
# 19712        NaN        NaN                 NaN         NaN         NaN
# 19714        NaN        NaN                 NaN         NaN         NaN
# 19715        NaN        NaN                 NaN         NaN         NaN
# 19716        NaN        NaN                 NaN         NaN         NaN
# 19717        NaN        NaN                 NaN         NaN         NaN
#
#       Q34_Part_12
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# ...           ...
# 19712         NaN
# 19714         NaN
# 19715         NaN
# 19716         NaN
# 19717         NaN
#
# [19354 rows x 213 columns]

# %% [markdown]
# # 2. Extract subsets
# for further steps we extract the relevant countries

# %%
india = df[df["country"] == "India"]

# %%
usa = df[df["country"] == "United States of America"]

# %% [markdown]
# ## 2.1 some plotting

# %%
df_tmp = df.copy()
df_tmp["country"] = np.where(df["country"] != np.nan, "global", df["country"])

# %%
global_gender_dist = round(100 * df["gender"].value_counts(normalize=True),2).to_frame().rename(columns={"gender" : "global"})
india_gender_dist = round(100 * india["gender"].value_counts(normalize=True),2).to_frame()
usa_gender_dist = round(100 * usa["gender"].value_counts(normalize=True),2).to_frame()
global_gender_dist
# Out:
#                          global
# Male                      81.69
# Female                    16.43
# Prefer not to say          1.63
# Prefer to self-describe    0.25

# %%
frames = [india, usa, df_tmp]
result = pd.concat(frames)

# %%
round(100 * india["gender"].value_counts(normalize=True),2).to_frame()
# Out:
#                          gender
# Male                      82.43
# Female                    16.33
# Prefer not to say          1.17
# Prefer to self-describe    0.06

# %%
round(100 * usa["gender"].value_counts(normalize=True),2).to_frame()
# Out:
#                          gender
# Male                      77.31
# Female                    20.25
# Prefer not to say          2.01
# Prefer to self-describe    0.43

# %%
india_female_count = len(india[india["Q2"] == "Female"])

# %% [markdown]
# ### 2.1.0 Fig Standards

# %%
figure_size = (12,6)

# %% [markdown]
# ### 2.1.1 Gender

# %%
fig , ax = plt.subplots(figsize=figure_size)
sns.countplot(data=result, x="gender", hue="country").set(xlabel="Gender");

# %% [markdown]
# ### 2.1.2 Age

# %%
fig , ax = plt.subplots(figsize=figure_size)
sns.countplot(data=result, x="age", hue="country").set(xlabel="Age");

# %%
india_male_count = len(india[india["Q2"] == "Male"])

# %%
india_female_count = len(india[india["Q2"] == "Female"])

# %%
print("India male proportion: ", round(india_male_count/len(india), 2))
# Out:
# India male proportion:  0.83

# %%
print("India female proportion: ", round(india_female_count/len(india), 2))
# Out:
# India female proportion:  0.16

# %%
usa_male_count = len(usa[usa["Q2"] == "Male"])

# %%
usa_female_count = len(usa[usa["Q2"] == "Female"])

# %%
print("US male proportion: ", round(usa_male_count/len(usa), 2))
# Out:
# US male proportion:  0.77

# %%
print("US female proportion: ", round(usa_female_count/len(usa), 2))
# Out:
# US female proportion:  0.2

# %%
len(df)
# Out:
# 19718

# %%
global_male_count = len(df[df["Q2"] == "Male"])

# %%
global_female_count = len(df[df["Q2"] == "Female"])

# %%
print("Global male proportion: ", round(global_male_count/len(df), 2))
# Out:
# Global male proportion:  0.82

# %%
print("Global female proportion: ", round(global_female_count/len(df), 2))
# Out:
# Global female proportion:  0.16
